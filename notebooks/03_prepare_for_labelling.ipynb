# %%
import pandas as pd
import re
import openpyxl

# %%
emails_df = pd.read_csv('../data/02_cleaned_emails_unlabelled_internal.csv')
emails_df.head(5)
# Out:
#                                     Date                     From  \
# 0   Fri, 4 May 2001 13:51:00 -0700 (PDT)  phillip.allen@enron.com
# 1  Mon, 23 Oct 2000 06:13:00 -0700 (PDT)  phillip.allen@enron.com
# 2  Tue, 22 Aug 2000 07:44:00 -0700 (PDT)  phillip.allen@enron.com
# 3  Mon, 16 Oct 2000 06:42:00 -0700 (PDT)  phillip.allen@enron.com
# 4  Fri, 13 Oct 2000 06:45:00 -0700 (PDT)  phillip.allen@enron.com
#
#                                                  To  \
# 0                           john.lavorato@enron.com
# 1                             randall.gay@enron.com
# 2  david.l.johnson@enron.com, john.shafer@enron.com
# 3                        buck.buckner@honeywell.com
# 4                        stagecoachmama@hotmail.com
#
#                                              Subject           X_From  \
# 0                                                Re:  Phillip K Allen
# 1                                         No Subject  Phillip K Allen
# ...

# %%
emails_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72012 entries, 0 to 72011
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     72012 non-null  object
#  1   From     72012 non-null  object
#  2   To       72012 non-null  object
#  3   Subject  72012 non-null  object
#  4   X_From   72012 non-null  object
#  5   X_To     72012 non-null  object
#  6   Message  72012 non-null  object
# dtypes: object(7)
# memory usage: 3.8+ MB

# %%
emails_df.describe(include='object').T
# Out:
#          count unique                                                top  freq
# Date     72012  67840              Mon, 31 Dec 1979 16:00:00 -0800 (PST)   121
# From     72012   5054                            jeff.dasovich@enron.com  1926
# To       72012  26737                               tana.jones@enron.com   930
# Subject  72012  53055                                         No Subject  2443
# X_From   72012   7392                                           Kay Mann  1690
# X_To     72012  31048                                         Tana Jones   826
# Message  72012  72012  Traveling to have a business meeting takes the...     1

# %%
emails_df['DISC'] = ""
emails_df
# Out:
#                                         Date                     From  \
# 0       Fri, 4 May 2001 13:51:00 -0700 (PDT)  phillip.allen@enron.com
# 1      Mon, 23 Oct 2000 06:13:00 -0700 (PDT)  phillip.allen@enron.com
# 2      Tue, 22 Aug 2000 07:44:00 -0700 (PDT)  phillip.allen@enron.com
# 3      Mon, 16 Oct 2000 06:42:00 -0700 (PDT)  phillip.allen@enron.com
# 4      Fri, 13 Oct 2000 06:45:00 -0700 (PDT)  phillip.allen@enron.com
# ...                                      ...                      ...
# 72007   Wed, 9 Jan 2002 07:30:16 -0800 (PST)  john.zufferli@enron.com
# 72008   Wed, 2 Jan 2002 09:55:40 -0800 (PST)  john.zufferli@enron.com
# 72009  Thu, 20 Dec 2001 09:51:58 -0800 (PST)  john.zufferli@enron.com
# 72010  Wed, 12 Dec 2001 09:14:32 -0800 (PST)  john.zufferli@enron.com
# 72011  Wed, 28 Nov 2001 13:30:11 -0800 (PST)  john.zufferli@enron.com
#
#                                                      To  \
# 0                               john.lavorato@enron.com
# ...

# %%
emails_df_trimmed = emails_df.drop(columns=['X_To', 'X_From'])
emails_df_trimmed.to_excel('../data/03_emails_unlabelled.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# IllegalCharacterError                     Traceback (most recent call last)
# Cell In[29], line 2
#       1 emails_df_trimmed = emails_df.drop(columns=['X_To', 'X_From'])
# ----> 2 emails_df_trimmed.to_excel('../data/03_emails_unlabelled.xlsx', index=False)
#
# File ~/Portfo/disc-predictor-for-business/business-disc/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
