# %%
import pandas as pd
import re

# %%
emails_df = pd.read_csv('../data/emails_handled_missing.csv')
emails_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 emails_df = pd.read_csv('../data/emails_handled_missing.csv')
#       2 emails_df.head(5)
#
# File ~/Portfo/disc-predictor-for-business/business-disc/lib/python3.12/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Portfo/disc-predictor-for-business/business-disc/lib/python3.12/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
emails_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495554 entries, 0 to 495553
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Message-ID                 495554 non-null  object
#  1   Date                       495554 non-null  object
#  2   From                       495554 non-null  object
#  3   To                         495554 non-null  object
#  4   Subject                    478886 non-null  object
#  5   Mime-Version               495554 non-null  float64
#  6   Content-Type               495554 non-null  object
#  7   Content-Transfer-Encoding  495554 non-null  object
#  8   X-From                     495554 non-null  object
#  9   X-To                       495554 non-null  object
#  10  X-Folder                   495554 non-null  object
#  11  X-Origin                   495554 non-null  object
#  12  X-FileName                 495007 non-null  object
# ...

# %%
emails_df.describe(include='object').T
# Out:
#                             count  unique  \
# Message-ID                 495554  495554
# Date                       495554  217515
# From                       495554   19752
# To                         495554   58563
# Subject                    478886  169506
# Content-Type               495554       2
# Content-Transfer-Encoding  495554   29666
# X-From                     495554   26891
# X-To                       495554   72027
# X-Folder                   495554    5127
# X-Origin                   495554     259
# X-FileName                 495007    3520
# Message-Body               495553  241201
#
#                                                                          top  \
# Message-ID                       18782981.1075855378110.JavaMail.evans@thyme
# Date                                   Mon, 31 Dec 1979 16:00:00 -0800 (PST)
# From                                                      kay.mann@enron.com
# ...
