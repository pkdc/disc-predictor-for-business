# %%
import pandas as pd
import numpy as np

# %%
emails_df = pd.read_csv('../data/emails_labelled_100.csv')

# %%
emails_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           102 non-null    object
#  1   From           102 non-null    object
#  2   Message        102 non-null    object
#  3   Subject        102 non-null    object
#  4   To             102 non-null    object
#  5   X_From         102 non-null    object
#  6   X_To           102 non-null    object
#  7   annotation_id  102 non-null    int64
#  8   annotator      102 non-null    int64
#  9   created_at     102 non-null    object
#  10  id             102 non-null    int64
#  11  lead_time      102 non-null    float64
#  12  sentiment      102 non-null    object
#  13  updated_at     102 non-null    object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 11.3+ KB

# %%
emails_df = emails_df.drop(columns=['X_From', 'X_To', 'annotation_id', 'annotator', 'created_at', 'id', 'lead_time', 'updated_at'])
emails_df
# Out:
#                                       Date                         From  \
# 0     Fri, 4 May 2001 13:51:00 -0700 (PDT)      phillip.allen@enron.com
# 1    Mon, 23 Oct 2000 06:13:00 -0700 (PDT)      phillip.allen@enron.com
# 2    Tue, 22 Aug 2000 07:44:00 -0700 (PDT)      phillip.allen@enron.com
# 3    Mon, 16 Oct 2000 06:42:00 -0700 (PDT)      phillip.allen@enron.com
# 4    Fri, 13 Oct 2000 06:45:00 -0700 (PDT)      phillip.allen@enron.com
# ..                                     ...                          ...
# 97   Thu, 26 Jul 2001 15:06:33 -0700 (PDT)  rajneesh.salhotra@enron.com
# 98   Tue, 12 Jun 2001 12:37:00 -0700 (PDT)        mark.taylor@enron.com
# 99   Mon, 30 Apr 2001 03:20:00 -0700 (PDT)   suzanne.calcagno@enron.com
# 100  Thu, 15 Nov 2001 13:48:50 -0800 (PST)          l..nowlan@enron.com
# 101  Fri, 11 Jan 2002 14:51:53 -0800 (PST)       kathy.reeves@enron.com
#
#                                                Message  \
# ...

# %%
emails_df['sentiment'] = emails_df['sentiment'].replace('N')
